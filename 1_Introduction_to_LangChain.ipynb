# %% [markdown]
# # Big thanks to Nitish Sir.

# %% [markdown]
# ## In this complete LangChain Module I have reffered CampusX tutorials.

# %% [markdown]
# # 🧠 What is LangChain?
#
# LangChain is an open-source framework designed to build powerful applications using Large Language Models (LLMs) like GPT-4, Claude, and others.
#
# Think of it as a toolbox that helps you:
#
# * Connect LLMs to external data (PDFs, websites, databases, etc.)
#
# * Build chains of thought (multi-step reasoning)
#
# * Use memory in conversations
#
# * Interact with APIs, tools, and agents
#
# LangChain = LLMs + External Tools + Data + Reasoning

# %% [markdown]
# # ❓ Why LangChain?
#
# While LLMs like ChatGPT are powerful, they:
#
# * Can’t access real-time or custom data (like your documents or database)
#
# * Lack long-term memory
#
# * Struggle with multi-step workflows (e.g., Search → Summarize → Email)
#
# LangChain solves these problems by:
#
# * Adding retrieval (like RAG) from your files or vector DBs
#
# * Supporting agents that can make decisions & call tools
#
# * Allowing you to chain multiple prompts and actions together
#
# * Integrating with APIs, databases, and 3rd-party services

# %% [markdown]
# # ✅ Benefits of Using LangChain
#
# 🔹 Feature	💡 Benefit
#
# 🧱 Modular Framework	Plug-and-play components: LLMs, prompts, tools, memory, chains
#
# 🧠 Memory Support	Maintains context over long conversations
#
# 📄 Document Interaction (RAG)	Ask questions to your PDFs, Notion docs, websites, etc.
#
# ⚙️ Agent Support	Build smart assistants that think and act dynamically
#
# 🧰 Tool Integration	Use external tools like Google Search, APIs, Databases
#
# 🚀 Fast Prototyping	Quickly build MVPs or prototypes of AI-powered apps
#
# 🧩 Scalable	Works well with enterprise workflows and can be deployed easily
#
# 📊 LangSmith Integration	Visual debugging, tracing, and evaluating your LLM app

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ![3.png](attachment:3.png)
